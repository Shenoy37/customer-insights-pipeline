# %%
datasets = [
    {"file_name":"orders"},
    {"file_name":"customers"},
    {"file_name":"products"},
    {"file_name":"regions"},
    
]

# %% [markdown]
# ## Dynamic way to input data using a job

# %%
# datasets used as an input for read and write from every location
dbutils.jobs.taskValues.set("output_dataset", datasets)
