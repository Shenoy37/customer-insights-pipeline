# %%
df = spark.read.format("parquet").load(f"abfss://bronze@azuredatabricksete.dfs.core.windows.net/regions")

# %%
display(df)

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@azuredatabricksete.dfs.core.windows.net/regions")
